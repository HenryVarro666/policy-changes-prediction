# %% [markdown]
# # 2021 Policy Data

# %%
import pandas as pd

# %%
df=pd.read_csv('./data/data_policy_2022.csv')
df
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220101
# 1           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220102
# 2           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220103
# 3           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220104
# 4           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 37123    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220410
# 37124    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220411
# 37125    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220412
# 37126    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220413
# 37127    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220414
#
#        C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  ...  \
# 0                    1.0      1.0      NaN                   0.0  ...
# 1                    1.0      1.0      NaN                   0.0  ...
# 2                    1.0      1.0      NaN                   0.0  ...
# 3                    1.0      1.0      NaN                   0.0  ...
# 4                    1.0      1.0      NaN                   0.0  ...
# ...                  ...      ...      ...                   ...  ...
# 37123                2.0      1.0      NaN                   2.0  ...
# 37124                2.0      1.0      NaN                   2.0  ...
# 37125                NaN      NaN      NaN                   NaN  ...
# 37126                NaN      NaN      NaN                   NaN  ...
# 37127                NaN      NaN      NaN                   NaN  ...
#
#        StringencyIndex StringencyIndexForDisplay  StringencyLegacyIndex  \
# 0                41.67                     41.67                   50.0
# 1                41.67                     41.67                   50.0
# 2                41.67                     41.67                   50.0
# 3                41.67                     41.67                   50.0
# 4                41.67                     41.67                   50.0
# ...                ...                       ...                    ...
# 37123            61.11                     61.11                   65.0
# 37124            61.11                     61.11                   65.0
# 37125              NaN                     61.11                    NaN
# 37126              NaN                     61.11                    NaN
# 37127              NaN                     61.11                    NaN
#
#        StringencyLegacyIndexForDisplay GovernmentResponseIndex  \
# 0                                 50.0                   44.27
# 1                                 50.0                   44.27
# 2                                 50.0                   44.27
# 3                                 50.0                   44.27
# 4                                 50.0                   44.27
# ...                                ...                     ...
# 37123                             65.0                   51.56
# 37124                             65.0                   51.56
# 37125                             65.0                     NaN
# 37126                             65.0                     NaN
# 37127                             65.0                     NaN
#
#        GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 0                                  44.27                   47.02
# 1                                  44.27                   47.02
# 2                                  44.27                   47.02
# 3                                  44.27                   47.02
# 4                                  44.27                   47.02
# ...                                  ...                     ...
# 37123                              51.56                   58.93
# 37124                              51.56                   58.93
# 37125                              51.56                     NaN
# 37126                              51.56                     NaN
# 37127                              51.56                     NaN
#
#       ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 0                                47.02                  25.0
# 1                                47.02                  25.0
# 2                                47.02                  25.0
# 3                                47.02                  25.0
# 4                                47.02                  25.0
# ...                                ...                   ...
# 37123                            58.93                   0.0
# 37124                            58.93                   0.0
# 37125                            58.93                   NaN
# 37126                            58.93                   NaN
# 37127                            58.93                   NaN
#
#        EconomicSupportIndexForDisplay
# 0                                25.0
# 1                                25.0
# 2                                25.0
# 3                                25.0
# 4                                25.0
# ...                               ...
# 37123                             0.0
# 37124                             0.0
# 37125                             0.0
# 37126                             0.0
# 37127                             0.0
#
# [37128 rows x 86 columns]

# %% [markdown]
# ## China policy data

# %%
df_CHN = df.loc[df['CountryName']=='China']
df_CHN
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 8320        China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220101
# 8321        China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220102
# 8322        China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220103
# 8323        China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220104
# 8324        China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 11643       China         CHN        NaN        NaN    NAT_TOTAL  20220410
# 11644       China         CHN        NaN        NaN    NAT_TOTAL  20220411
# 11645       China         CHN        NaN        NaN    NAT_TOTAL  20220412
# 11646       China         CHN        NaN        NaN    NAT_TOTAL  20220413
# 11647       China         CHN        NaN        NaN    NAT_TOTAL  20220414
#
#        C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  ...  \
# 8320                 1.0      1.0      NaN                   1.0  ...
# 8321                 1.0      1.0      NaN                   1.0  ...
# 8322                 1.0      1.0      NaN                   1.0  ...
# 8323                 1.0      1.0      NaN                   1.0  ...
# 8324                 1.0      1.0      NaN                   1.0  ...
# ...                  ...      ...      ...                   ...  ...
# 11643                3.0      0.0      NaN                   2.0  ...
# 11644                NaN      NaN      NaN                   NaN  ...
# 11645                NaN      NaN      NaN                   NaN  ...
# 11646                NaN      NaN      NaN                   NaN  ...
# 11647                NaN      NaN      NaN                   NaN  ...
#
#        StringencyIndex StringencyIndexForDisplay  StringencyLegacyIndex  \
# 8320             56.94                     56.94                  65.00
# 8321             56.94                     56.94                  65.00
# 8322             56.94                     56.94                  65.00
# 8323             56.94                     56.94                  65.00
# 8324             56.94                     56.94                  65.00
# ...                ...                       ...                    ...
# 11643            75.46                     75.46                  70.95
# 11644              NaN                     75.46                    NaN
# 11645              NaN                     75.46                    NaN
# 11646              NaN                     75.46                    NaN
# 11647              NaN                     75.46                    NaN
#
#        StringencyLegacyIndexForDisplay GovernmentResponseIndex  \
# 8320                             65.00                   59.11
# 8321                             65.00                   59.11
# 8322                             65.00                   59.11
# 8323                             65.00                   59.11
# 8324                             65.00                   59.11
# ...                                ...                     ...
# 11643                            70.95                   77.34
# 11644                            70.95                     NaN
# 11645                            70.95                     NaN
# 11646                            70.95                     NaN
# 11647                            70.95                     NaN
#
#        GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 8320                               59.11                   67.56
# 8321                               59.11                   67.56
# 8322                               59.11                   67.56
# 8323                               59.11                   67.56
# 8324                               59.11                   67.56
# ...                                  ...                     ...
# 11643                              77.34                   79.46
# 11644                              77.34                     NaN
# 11645                              77.34                     NaN
# 11646                              77.34                     NaN
# 11647                              77.34                     NaN
#
#       ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 8320                             67.56                   0.0
# 8321                             67.56                   0.0
# 8322                             67.56                   0.0
# 8323                             67.56                   0.0
# 8324                             67.56                   0.0
# ...                                ...                   ...
# 11643                            79.46                  62.5
# 11644                            79.46                   NaN
# 11645                            79.46                   NaN
# 11646                            79.46                   NaN
# 11647                            79.46                   NaN
#
#        EconomicSupportIndexForDisplay
# 8320                              0.0
# 8321                              0.0
# 8322                              0.0
# 8323                              0.0
# 8324                              0.0
# ...                               ...
# 11643                            62.5
# 11644                            62.5
# 11645                            62.5
# 11646                            62.5
# 11647                            62.5
#
# [3328 rows x 86 columns]

# %%
df_CHN.head()
# Out:
#      CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 8320       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220101
# 8321       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220102
# 8322       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220103
# 8323       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220104
# 8324       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220105
#
#       C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  ...  \
# 8320                1.0      1.0      NaN                   1.0  ...
# 8321                1.0      1.0      NaN                   1.0  ...
# 8322                1.0      1.0      NaN                   1.0  ...
# 8323                1.0      1.0      NaN                   1.0  ...
# 8324                1.0      1.0      NaN                   1.0  ...
#
#       StringencyIndex StringencyIndexForDisplay  StringencyLegacyIndex  \
# 8320            56.94                     56.94                   65.0
# 8321            56.94                     56.94                   65.0
# 8322            56.94                     56.94                   65.0
# 8323            56.94                     56.94                   65.0
# 8324            56.94                     56.94                   65.0
#
#       StringencyLegacyIndexForDisplay GovernmentResponseIndex  \
# 8320                             65.0                   59.11
# 8321                             65.0                   59.11
# 8322                             65.0                   59.11
# 8323                             65.0                   59.11
# 8324                             65.0                   59.11
#
#       GovernmentResponseIndexForDisplay  ContainmentHealthIndex  \
# 8320                              59.11                   67.56
# 8321                              59.11                   67.56
# 8322                              59.11                   67.56
# 8323                              59.11                   67.56
# 8324                              59.11                   67.56
#
#      ContainmentHealthIndexForDisplay  EconomicSupportIndex  \
# 8320                            67.56                   0.0
# 8321                            67.56                   0.0
# 8322                            67.56                   0.0
# 8323                            67.56                   0.0
# 8324                            67.56                   0.0
#
#       EconomicSupportIndexForDisplay
# 8320                             0.0
# 8321                             0.0
# 8322                             0.0
# 8323                             0.0
# 8324                             0.0
#
# [5 rows x 86 columns]

# %%
### Numbers of columns

# %%
df_CHN.shape[1]
# Out:
# 86

# %%
### Numbers of lines

# %%
df_CHN.shape[0]
# Out:
# 3328

# %%
len(df_CHN)
# Out:
# 3328

# %%
df_CHN.to_csv(f'./data/2022_policy/CHN_policy_2022.csv')

# %% [markdown]
# ## America policy data

# %%
df_USA = df.loc[df['CountryCode']=='USA']
df_USA
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 30784  United States         USA        NaN        NaN    NAT_TOTAL  20220101
# 30785  United States         USA        NaN        NaN    NAT_TOTAL  20220102
# 30786  United States         USA        NaN        NaN    NAT_TOTAL  20220103
# 30787  United States         USA        NaN        NaN    NAT_TOTAL  20220104
# 30788  United States         USA        NaN        NaN    NAT_TOTAL  20220105
# ...              ...         ...        ...        ...          ...       ...
# 36187  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220410
# 36188  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220411
# 36189  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220412
# 36190  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220413
# 36191  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220414
#
#        C1_School closing  C1_Flag  \
# 30784                2.0      0.0
# 30785                2.0      0.0
# 30786                2.0      0.0
# 30787                2.0      0.0
# 30788                2.0      0.0
# ...                  ...      ...
# 36187                NaN      NaN
# 36188                NaN      NaN
# 36189                NaN      NaN
# 36190                NaN      NaN
# 36191                NaN      NaN
#
#                                                 C1_Notes  \
# 30784                                                NaN
# 30785                                                NaN
# 30786                                                NaN
# 30787  Several school districts across the country ar...
# 30788                                                NaN
# ...                                                  ...
# 36187                                                NaN
# 36188                                                NaN
# 36189                                                NaN
# 36190                                                NaN
# 36191                                                NaN
#
#        C2_Workplace closing  ...  StringencyIndex StringencyIndexForDisplay  \
# 30784                   2.0  ...            53.24                     53.24
# 30785                   2.0  ...            53.24                     53.24
# 30786                   2.0  ...            53.24                     53.24
# 30787                   2.0  ...            53.24                     53.24
# 30788                   2.0  ...            53.24                     53.24
# ...                     ...  ...              ...                       ...
# 36187                   NaN  ...              NaN                       NaN
# 36188                   NaN  ...              NaN                       NaN
# 36189                   NaN  ...              NaN                       NaN
# 36190                   NaN  ...              NaN                       NaN
# 36191                   NaN  ...              NaN                       NaN
#
#        StringencyLegacyIndex  StringencyLegacyIndexForDisplay  \
# 30784                  63.81                            63.81
# 30785                  63.81                            63.81
# 30786                  63.81                            63.81
# 30787                  63.81                            63.81
# 30788                  63.81                            63.81
# ...                      ...                              ...
# 36187                    NaN                              NaN
# 36188                    NaN                              NaN
# 36189                    NaN                              NaN
# 36190                    NaN                              NaN
# 36191                    NaN                              NaN
#
#       GovernmentResponseIndex  GovernmentResponseIndexForDisplay  \
# 30784                    52.6                               52.6
# 30785                    52.6                               52.6
# 30786                    52.6                               52.6
# 30787                    52.6                               52.6
# 30788                    52.6                               52.6
# ...                       ...                                ...
# 36187                     NaN                                NaN
# 36188                     NaN                                NaN
# 36189                     NaN                                NaN
# 36190                     NaN                                NaN
# 36191                     NaN                                NaN
#
#        ContainmentHealthIndex ContainmentHealthIndexForDisplay  \
# 30784                   60.12                            60.12
# 30785                   60.12                            60.12
# 30786                   60.12                            60.12
# 30787                   60.12                            60.12
# 30788                   60.12                            60.12
# ...                       ...                              ...
# 36187                     NaN                              NaN
# 36188                     NaN                              NaN
# 36189                     NaN                              NaN
# 36190                     NaN                              NaN
# 36191                     NaN                              NaN
#
#        EconomicSupportIndex  EconomicSupportIndexForDisplay
# 30784                   0.0                             0.0
# 30785                   0.0                             0.0
# 30786                   0.0                             0.0
# 30787                   0.0                             0.0
# 30788                   0.0                             0.0
# ...                     ...                             ...
# 36187                   NaN                             NaN
# 36188                   NaN                             NaN
# 36189                   NaN                             NaN
# 36190                   NaN                             NaN
# 36191                   NaN                             NaN
#
# [5408 rows x 86 columns]

# %%
df_USA.to_csv(f'./data/2022_policy/USA_policy_2022.csv')

# %% [markdown]
# ## Italy policy data

# %%
df_ITA = df.loc[df['CountryName']=='Italy']
df_ITA
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 21112       Italy         ITA        NaN        NaN    NAT_TOTAL  20220101
# 21113       Italy         ITA        NaN        NaN    NAT_TOTAL  20220102
# 21114       Italy         ITA        NaN        NaN    NAT_TOTAL  20220103
# 21115       Italy         ITA        NaN        NaN    NAT_TOTAL  20220104
# 21116       Italy         ITA        NaN        NaN    NAT_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 21211       Italy         ITA        NaN        NaN    NAT_TOTAL  20220410
# 21212       Italy         ITA        NaN        NaN    NAT_TOTAL  20220411
# 21213       Italy         ITA        NaN        NaN    NAT_TOTAL  20220412
# 21214       Italy         ITA        NaN        NaN    NAT_TOTAL  20220413
# 21215       Italy         ITA        NaN        NaN    NAT_TOTAL  20220414
#
#        C1_School closing  C1_Flag  \
# 21112                2.0      1.0
# 21113                2.0      1.0
# 21114                2.0      1.0
# 21115                2.0      1.0
# 21116                2.0      1.0
# ...                  ...      ...
# 21211                NaN      NaN
# 21212                NaN      NaN
# 21213                NaN      NaN
# 21214                NaN      NaN
# 21215                NaN      NaN
#
#                                                 C1_Notes  \
# 21112                                                NaN
# 21113                                                NaN
# 21114  no changes in policy, green passes are still r...
# 21115                                                NaN
# 21116                                                NaN
# ...                                                  ...
# 21211                                                NaN
# 21212                                                NaN
# 21213                                                NaN
# 21214                                                NaN
# 21215                                                NaN
#
#        C2_Workplace closing  ...  StringencyIndex StringencyIndexForDisplay  \
# 21112                   3.0  ...            76.85                     76.85
# 21113                   3.0  ...            76.85                     76.85
# 21114                   3.0  ...            76.85                     76.85
# 21115                   3.0  ...            76.85                     76.85
# 21116                   3.0  ...            76.85                     76.85
# ...                     ...  ...              ...                       ...
# 21211                   NaN  ...              NaN                     53.70
# 21212                   NaN  ...              NaN                     53.70
# 21213                   NaN  ...              NaN                     53.70
# 21214                   NaN  ...              NaN                     53.70
# 21215                   NaN  ...              NaN                     53.70
#
#        StringencyLegacyIndex  StringencyLegacyIndexForDisplay  \
# 21112                   88.1                            88.10
# 21113                   88.1                            88.10
# 21114                   88.1                            88.10
# 21115                   88.1                            88.10
# 21116                   88.1                            88.10
# ...                      ...                              ...
# 21211                    NaN                            71.43
# 21212                    NaN                            71.43
# 21213                    NaN                            71.43
# 21214                    NaN                            71.43
# 21215                    NaN                            71.43
#
#       GovernmentResponseIndex  GovernmentResponseIndexForDisplay  \
# 21112                   82.29                              82.29
# 21113                   82.29                              82.29
# 21114                   82.29                              82.29
# 21115                   82.29                              82.29
# 21116                   82.29                              82.29
# ...                       ...                                ...
# 21211                     NaN                              64.58
# 21212                     NaN                              64.58
# 21213                     NaN                              64.58
# 21214                     NaN                              64.58
# 21215                     NaN                              64.58
#
#        ContainmentHealthIndex ContainmentHealthIndexForDisplay  \
# 21112                   83.33                            83.33
# 21113                   83.33                            83.33
# 21114                   83.33                            83.33
# 21115                   83.33                            83.33
# 21116                   83.33                            83.33
# ...                       ...                              ...
# 21211                     NaN                            66.67
# 21212                     NaN                            66.67
# 21213                     NaN                            66.67
# 21214                     NaN                            66.67
# 21215                     NaN                            66.67
#
#        EconomicSupportIndex  EconomicSupportIndexForDisplay
# 21112                  75.0                            75.0
# 21113                  75.0                            75.0
# 21114                  75.0                            75.0
# 21115                  75.0                            75.0
# 21116                  75.0                            75.0
# ...                     ...                             ...
# 21211                   NaN                            50.0
# 21212                   NaN                            50.0
# 21213                   NaN                            50.0
# 21214                   NaN                            50.0
# 21215                   NaN                            50.0
#
# [104 rows x 86 columns]

# %%
df_ITA.to_csv(f'./data/2022_policy/ITA_policy_2022.csv')

# %% [markdown]
# ## UK policy data

# %%
df_UK = df.loc[df['CountryName']=='United Kingdom']
df_UK
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 14560  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 14561  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 14562  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 14563  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 14564  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 15075  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 15076  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 15077  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 15078  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 15079  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
#
#            Date  C1_School closing  C1_Flag  \
# 14560  20220101                1.0      1.0
# 14561  20220102                1.0      1.0
# 14562  20220103                1.0      1.0
# 14563  20220104                1.0      1.0
# 14564  20220105                1.0      1.0
# ...         ...                ...      ...
# 15075  20220410                NaN      NaN
# 15076  20220411                NaN      NaN
# 15077  20220412                NaN      NaN
# 15078  20220413                NaN      NaN
# 15079  20220414                NaN      NaN
#
#                                                 C1_Notes  \
# 14560                                                NaN
# 14561                                                NaN
# 14562                                                NaN
# 14563  Face coverings required in schools    http://w...
# 14564                                                NaN
# ...                                                  ...
# 15075                                                NaN
# 15076                                                NaN
# 15077                                                NaN
# 15078                                                NaN
# 15079                                                NaN
#
#        C2_Workplace closing  ...  StringencyIndex StringencyIndexForDisplay  \
# 14560                   2.0  ...            48.61                     48.61
# 14561                   2.0  ...            48.61                     48.61
# 14562                   2.0  ...            48.61                     48.61
# 14563                   2.0  ...            48.61                     48.61
# 14564                   2.0  ...            48.61                     48.61
# ...                     ...  ...              ...                       ...
# 15075                   NaN  ...              NaN                       NaN
# 15076                   NaN  ...              NaN                       NaN
# 15077                   NaN  ...              NaN                       NaN
# 15078                   NaN  ...              NaN                       NaN
# 15079                   NaN  ...              NaN                       NaN
#
#        StringencyLegacyIndex  StringencyLegacyIndexForDisplay  \
# 14560                  58.33                            58.33
# 14561                  58.33                            58.33
# 14562                  58.33                            58.33
# 14563                  58.33                            58.33
# 14564                  58.33                            58.33
# ...                      ...                              ...
# 15075                    NaN                              NaN
# 15076                    NaN                              NaN
# 15077                    NaN                              NaN
# 15078                    NaN                              NaN
# 15079                    NaN                              NaN
#
#       GovernmentResponseIndex  GovernmentResponseIndexForDisplay  \
# 14560                   51.04                              51.04
# 14561                   51.04                              51.04
# 14562                   51.04                              51.04
# 14563                   51.04                              51.04
# 14564                   51.04                              51.04
# ...                       ...                                ...
# 15075                     NaN                                NaN
# 15076                     NaN                                NaN
# 15077                     NaN                                NaN
# 15078                     NaN                                NaN
# 15079                     NaN                                NaN
#
#        ContainmentHealthIndex ContainmentHealthIndexForDisplay  \
# 14560                   54.76                            54.76
# 14561                   54.76                            54.76
# 14562                   54.76                            54.76
# 14563                   54.76                            54.76
# 14564                   54.76                            54.76
# ...                       ...                              ...
# 15075                     NaN                              NaN
# 15076                     NaN                              NaN
# 15077                     NaN                              NaN
# 15078                     NaN                              NaN
# 15079                     NaN                              NaN
#
#        EconomicSupportIndex  EconomicSupportIndexForDisplay
# 14560                  25.0                            25.0
# 14561                  25.0                            25.0
# 14562                  25.0                            25.0
# 14563                  25.0                            25.0
# 14564                  25.0                            25.0
# ...                     ...                             ...
# 15075                   NaN                             NaN
# 15076                   NaN                             NaN
# 15077                   NaN                             NaN
# 15078                   NaN                             NaN
# 15079                   NaN                             NaN
#
# [520 rows x 86 columns]

# %%
df_UK.to_csv(f'./data/2022_policy/UK_policy_2022.csv')
