# %% [markdown]
# # A basic template to apply any models to train on the collected data

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from scipy.stats import zscore
from sklearn import preprocessing
pd.set_option('display.max_columns', None)
import graphviz
plt.rcParams['figure.figsize'] = [18, 10]

from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
trainDF = pd.read_csv('../outputs/trainXY.csv',parse_dates=['date_implement'])
trainDF = trainDF.sample(frac=1)

# %%
trainDF.head()
trainDF = trainDF.dropna()

# %% [markdown]
# # Selecting a unique policy

# %%
policies = trainDF['policy'].unique()
policy_selected = policies[12]
print(f'Selected Policy: {policy_selected}')
trainDF = trainDF[trainDF['policy']==policy_selected]
# Out:
# Selected Policy: C6_Stay at home requirements

# %%
# Finalizing Indexes so we can drop state names 
trainDF = trainDF.reset_index(drop=True)

# Get a list of columns with features 
columns = trainDF.columns.to_list()

# %%
Y_columns = [x for x in columns if 'Y_' in x]

# %%
X_columns = [x for x in columns if 'Y_' not in x and 'Unnamed' not in x]

X_columns.remove('date_implement')
# X_columns.remove('policy')
X_columns.remove('state_x')
X_columns.remove('policy_type')
X_columns.remove('stateName')
X_columns.remove('CEN_stateCode')
X_columns.remove('submission_date')
X_columns.remove('state_y')

X_columns.remove('caseInterpolate_gauss3')
X_columns.remove('caseInterpolate_MA7')
X_columns.remove('caseInterpolate_savitzky31_3')
X_columns.remove('caseInterpolate_gauss8')
X_columns.remove('new_case_zscore')
X_columns.remove('new_case')
X_columns.remove('policy')

# %%
X = trainDF[X_columns]
y = trainDF[Y_columns]

# %%
y
# Out:
#      Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                               1.0                             0.530612
# 1                              -1.0                            -5.693878
# 2                              -1.0                            -6.591837
# 3                               1.0                             0.316327
# 4                              -1.0                            -4.673469
# ..                              ...                                  ...
# 142                            -1.0                            -2.704082
# 143                             1.0                             0.255102
# 144                            -1.0                           -78.285714
# 145                            -1.0                            -4.346939
# 146                             1.0                           106.408163
#
#      Y_SLOPE_caseInterpolate_MA7_14  Y_TREND_caseInterpolate_MA7_21  \
# 0                          0.221538                             1.0
# 1                          1.839451                             1.0
# 2                         -0.555714                            -1.0
# 3                         -1.925934                            -1.0
# 4                         -5.547912                            -1.0
# ..                              ...                             ...
# 142                       -1.063297                            -1.0
# 143                        0.117802                             1.0
# 144                      -90.662967                            -1.0
# 145                       -3.046813                            -1.0
# 146                      157.210330                             1.0
#
#      Y_TRENDQUANT_caseInterpolate_MA7_21  Y_SLOPE_caseInterpolate_MA7_21  \
# 0                               0.353741                        0.221538
# 1                               3.598639                        1.839451
# 2                              -1.904762                       -0.555714
# 3                              -0.523810                       -1.925934
# 4                              -5.353741                       -5.547912
# ..                                   ...                             ...
# 142                            -0.945578                       -1.063297
# 143                             0.170068                        0.117802
# 144                           -83.102041                      -90.662967
# 145                            -2.319728                       -3.046813
# 146                           120.693878                      157.210330
#
#      Y_TREND_caseInterpolate_MA7_28  Y_TRENDQUANT_caseInterpolate_MA7_28  \
# 0                               1.0                             0.265306
# 1                              -1.0                           -13.321429
# 2                               1.0                             1.943878
# 3                               1.0                             0.076531
# 4                              -1.0                            -4.831633
# ..                              ...                                  ...
# 142                             1.0                             0.290816
# 143                             1.0                             0.127551
# 144                            -1.0                           -79.255102
# 145                            -1.0                           -12.647959
# 146                             1.0                           107.897959
#
#      Y_SLOPE_caseInterpolate_MA7_28  Y_TREND_caseInterpolate_gauss8_14  \
# 0                          0.221538                                1.0
# 1                          1.839451                               -1.0
# 2                         -0.555714                               -1.0
# 3                         -1.925934                               -1.0
# 4                         -5.547912                               -1.0
# ..                              ...                                ...
# 142                       -1.063297                               -1.0
# 143                        0.117802                                1.0
# 144                      -90.662967                               -1.0
# 145                       -3.046813                               -1.0
# 146                      157.210330                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_14  \
# 0                                  1.571429
# 1                                 -2.500000
# 2                                 -4.500000
# 3                                 -2.142857
# 4                                 -3.571429
# ..                                      ...
# 142                               -1.571429
# 143                                4.357143
# 144                              -61.071429
# 145                               -5.642857
# 146                               39.428571
#
#      Y_SLOPE_caseInterpolate_gauss8_14  Y_TREND_caseInterpolate_gauss8_21  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                               -1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_21  \
# 0                                  1.142857
# 1                                 -2.523810
# 2                                 -2.095238
# 3                                 -1.952381
# 4                                 -4.380952
# ..                                      ...
# 142                               -1.047619
# 143                                3.000000
# 144                              -70.857143
# 145                               -6.857143
# 146                               70.619048
#
#      Y_SLOPE_caseInterpolate_gauss8_21  Y_TREND_caseInterpolate_gauss8_28  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                                1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_28  \
# 0                                  0.857143
# 1                                 -2.464286
# 2                                  0.678571
# 3                                 -1.678571
# 4                                 -5.357143
# ..                                      ...
# 142                               -0.392857
# 143                                2.250000
# 144                              -77.750000
# 145                              -10.678571
# 146                               78.857143
#
#      Y_SLOPE_caseInterpolate_gauss8_28  Y_TREND_caseInterpolate_gauss3_14  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                               -1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_14  \
# 0                                  1.000000
# 1                                 -3.071429
# 2                                 -7.071429
# 3                                 -0.571429
# 4                                 -3.785714
# ..                                      ...
# 142                               -1.928571
# 143                                1.071429
# 144                              -57.000000
# 145                               -8.785714
# 146                               36.928571
#
#      Y_SLOPE_caseInterpolate_gauss3_14  Y_TREND_caseInterpolate_gauss3_21  \
# 0                             0.452308                                1.0
# 1                             0.220769                                1.0
# 2                            -2.706154                               -1.0
# 3                            -1.645385                               -1.0
# 4                            -5.088462                               -1.0
# ..                                 ...                                ...
# 142                          -2.084615                               -1.0
# 143                           0.359231                                1.0
# 144                         -85.017692                               -1.0
# 145                          -3.233846                               -1.0
# 146                         120.459231                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_21  \
# 0                                  0.714286
# 1                                  1.142857
# 2                                 -2.619048
# 3                                 -1.380952
# 4                                 -4.761905
# ..                                      ...
# 142                               -2.000000
# 143                                0.714286
# 144                              -81.190476
# 145                               -3.238095
# 146                               92.666667
#
#      Y_SLOPE_caseInterpolate_gauss3_21  Y_TREND_caseInterpolate_gauss3_28  \
# 0                             0.452308                                1.0
# 1                             0.220769                               -1.0
# 2                            -2.706154                               -1.0
# 3                            -1.645385                               -1.0
# 4                            -5.088462                               -1.0
# ..                                 ...                                ...
# 142                          -2.084615                                1.0
# 143                           0.359231                                1.0
# 144                         -85.017692                               -1.0
# 145                          -3.233846                               -1.0
# 146                         120.459231                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_28  Y_SLOPE_caseInterpolate_gauss3_28
# 0                                  0.535714                           0.452308
# 1                                 -5.428571                           0.220769
# 2                                 -0.428571                          -2.706154
# 3                                 -0.571429                          -1.645385
# 4                                 -4.535714                          -5.088462
# ..                                      ...                                ...
# 142                                0.250000                          -2.084615
# 143                                0.535714                           0.359231
# 144                              -70.321429                         -85.017692
# 145                               -8.571429                          -3.233846
# 146                               96.964286                         120.459231
#
# [147 rows x 27 columns]

# %% [markdown]
# # Encoding Policy Names

# %%
# X['policy'].unique()

# %%
# le = preprocessing.LabelEncoder()
# le.fit(X['policy'])
# print(le.classes_)

# %%
# X['policy'] = pd.Series(le.transform(X['policy']))
# original_policies_decoded = pd.Series(le.inverse_transform(X['policy']))

# %%
# for i in range(len(le.classes_)):
#     print(f'{i}: {le.classes_[i]}')

# %%
# unique_policy = X['policy'].unique()

# %% [markdown]
# ------

# %% [markdown]
# -------

# %% [markdown]
# # Train Models Here

# %%
y
# Out:
#      Y_TREND_caseInterpolate_MA7_14  Y_TRENDQUANT_caseInterpolate_MA7_14  \
# 0                               1.0                             0.530612
# 1                              -1.0                            -5.693878
# 2                              -1.0                            -6.591837
# 3                               1.0                             0.316327
# 4                              -1.0                            -4.673469
# ..                              ...                                  ...
# 142                            -1.0                            -2.704082
# 143                             1.0                             0.255102
# 144                            -1.0                           -78.285714
# 145                            -1.0                            -4.346939
# 146                             1.0                           106.408163
#
#      Y_SLOPE_caseInterpolate_MA7_14  Y_TREND_caseInterpolate_MA7_21  \
# 0                          0.221538                             1.0
# 1                          1.839451                             1.0
# 2                         -0.555714                            -1.0
# 3                         -1.925934                            -1.0
# 4                         -5.547912                            -1.0
# ..                              ...                             ...
# 142                       -1.063297                            -1.0
# 143                        0.117802                             1.0
# 144                      -90.662967                            -1.0
# 145                       -3.046813                            -1.0
# 146                      157.210330                             1.0
#
#      Y_TRENDQUANT_caseInterpolate_MA7_21  Y_SLOPE_caseInterpolate_MA7_21  \
# 0                               0.353741                        0.221538
# 1                               3.598639                        1.839451
# 2                              -1.904762                       -0.555714
# 3                              -0.523810                       -1.925934
# 4                              -5.353741                       -5.547912
# ..                                   ...                             ...
# 142                            -0.945578                       -1.063297
# 143                             0.170068                        0.117802
# 144                           -83.102041                      -90.662967
# 145                            -2.319728                       -3.046813
# 146                           120.693878                      157.210330
#
#      Y_TREND_caseInterpolate_MA7_28  Y_TRENDQUANT_caseInterpolate_MA7_28  \
# 0                               1.0                             0.265306
# 1                              -1.0                           -13.321429
# 2                               1.0                             1.943878
# 3                               1.0                             0.076531
# 4                              -1.0                            -4.831633
# ..                              ...                                  ...
# 142                             1.0                             0.290816
# 143                             1.0                             0.127551
# 144                            -1.0                           -79.255102
# 145                            -1.0                           -12.647959
# 146                             1.0                           107.897959
#
#      Y_SLOPE_caseInterpolate_MA7_28  Y_TREND_caseInterpolate_gauss8_14  \
# 0                          0.221538                                1.0
# 1                          1.839451                               -1.0
# 2                         -0.555714                               -1.0
# 3                         -1.925934                               -1.0
# 4                         -5.547912                               -1.0
# ..                              ...                                ...
# 142                       -1.063297                               -1.0
# 143                        0.117802                                1.0
# 144                      -90.662967                               -1.0
# 145                       -3.046813                               -1.0
# 146                      157.210330                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_14  \
# 0                                  1.571429
# 1                                 -2.500000
# 2                                 -4.500000
# 3                                 -2.142857
# 4                                 -3.571429
# ..                                      ...
# 142                               -1.571429
# 143                                4.357143
# 144                              -61.071429
# 145                               -5.642857
# 146                               39.428571
#
#      Y_SLOPE_caseInterpolate_gauss8_14  Y_TREND_caseInterpolate_gauss8_21  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                               -1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_21  \
# 0                                  1.142857
# 1                                 -2.523810
# 2                                 -2.095238
# 3                                 -1.952381
# 4                                 -4.380952
# ..                                      ...
# 142                               -1.047619
# 143                                3.000000
# 144                              -70.857143
# 145                               -6.857143
# 146                               70.619048
#
#      Y_SLOPE_caseInterpolate_gauss8_21  Y_TREND_caseInterpolate_gauss8_28  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                                1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss8_28  \
# 0                                  0.857143
# 1                                 -2.464286
# 2                                  0.678571
# 3                                 -1.678571
# 4                                 -5.357143
# ..                                      ...
# 142                               -0.392857
# 143                                2.250000
# 144                              -77.750000
# 145                              -10.678571
# 146                               78.857143
#
#      Y_SLOPE_caseInterpolate_gauss8_28  Y_TREND_caseInterpolate_gauss3_14  \
# 0                             0.906923                                1.0
# 1                            -2.403077                               -1.0
# 2                            -1.363846                               -1.0
# 3                            -1.816154                               -1.0
# 4                            -4.757692                               -1.0
# ..                                 ...                                ...
# 142                          -0.910769                               -1.0
# 143                           2.092308                                1.0
# 144                         -75.640769                               -1.0
# 145                          -7.318462                               -1.0
# 146                          85.520769                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_14  \
# 0                                  1.000000
# 1                                 -3.071429
# 2                                 -7.071429
# 3                                 -0.571429
# 4                                 -3.785714
# ..                                      ...
# 142                               -1.928571
# 143                                1.071429
# 144                              -57.000000
# 145                               -8.785714
# 146                               36.928571
#
#      Y_SLOPE_caseInterpolate_gauss3_14  Y_TREND_caseInterpolate_gauss3_21  \
# 0                             0.452308                                1.0
# 1                             0.220769                                1.0
# 2                            -2.706154                               -1.0
# 3                            -1.645385                               -1.0
# 4                            -5.088462                               -1.0
# ..                                 ...                                ...
# 142                          -2.084615                               -1.0
# 143                           0.359231                                1.0
# 144                         -85.017692                               -1.0
# 145                          -3.233846                               -1.0
# 146                         120.459231                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_21  \
# 0                                  0.714286
# 1                                  1.142857
# 2                                 -2.619048
# 3                                 -1.380952
# 4                                 -4.761905
# ..                                      ...
# 142                               -2.000000
# 143                                0.714286
# 144                              -81.190476
# 145                               -3.238095
# 146                               92.666667
#
#      Y_SLOPE_caseInterpolate_gauss3_21  Y_TREND_caseInterpolate_gauss3_28  \
# 0                             0.452308                                1.0
# 1                             0.220769                               -1.0
# 2                            -2.706154                               -1.0
# 3                            -1.645385                               -1.0
# 4                            -5.088462                               -1.0
# ..                                 ...                                ...
# 142                          -2.084615                                1.0
# 143                           0.359231                                1.0
# 144                         -85.017692                               -1.0
# 145                          -3.233846                               -1.0
# 146                         120.459231                                1.0
#
#      Y_TRENDQUANT_caseInterpolate_gauss3_28  Y_SLOPE_caseInterpolate_gauss3_28
# 0                                  0.535714                           0.452308
# 1                                 -5.428571                           0.220769
# 2                                 -0.428571                          -2.706154
# 3                                 -0.571429                          -1.645385
# 4                                 -4.535714                          -5.088462
# ..                                      ...                                ...
# 142                                0.250000                          -2.084615
# 143                                0.535714                           0.359231
# 144                              -70.321429                         -85.017692
# 145                               -8.571429                          -3.233846
# 146                               96.964286                         120.459231
#
# [147 rows x 27 columns]

# %%
X = X.apply(zscore)
y = y.apply(zscore)

# %%
from sklearn.datasets import load_iris
from sklearn import tree

# %%
clf = tree.DecisionTreeRegressor()

# %%
y_selected = y[['Y_SLOPE_caseInterpolate_MA7_21']]

# %%
clf = clf.fit(X, y_selected)

# %%
# dot_data = tree.export_graphviz(clf, out_file=None) 
# graph = graphviz.Source(dot_data) 
# graph.render("tree")

# %%
dot_data = tree.export_graphviz(clf, out_file=None, 
                     feature_names=X.columns.to_list(), 
                     filled=True, rounded=True,  
                     special_characters=True)  
graph = graphviz.Source(dot_data)  
graph.render(f'../outputs/TREEOP_{policy_selected}')
# Out:
# '../outputs/TREEOP_C6_Stay at home requirements.pdf'

# %% [markdown]
# # Most Important Features

# %%
# Random Forest 

regr = RandomForestRegressor(max_depth=100, random_state=0)
regr.fit(X, y_selected)
# Out:
# /var/folders/66/w1588p9n1654b1yky4q5nz580000gn/T/ipykernel_11659/3596666854.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   regr.fit(X, y_selected)
# RandomForestRegressor(max_depth=100, random_state=0)

# %%
def imp_df(column_names, importances):
    data = {
        'Feature': column_names,
        'Importance': importances,
    }
    df = pd.DataFrame(data) \
        .set_index('Feature') \
        .sort_values('Importance', ascending=False)

    return df

# %%
base_imp = imp_df(X.columns, regr.feature_importances_)
print(base_imp)
# Out:
#                                                  Importance
# Feature
# metric_change                                      0.321274
# S1_people_fully_vaccinated                         0.090440
# FD_moreThan10kCitizens                             0.073605
# S1_people_fully_vaccinated_per_hundred             0.060951
# CEN_Without Health Care Coverage                   0.042862
# S2_people_vaccinated                               0.037793
# S4_people_vaccinated                               0.034381
# CEN_Hispanic or Latino (of any race)               0.034286
# S4_people_fully_vaccinated                         0.032027
# CEN_Total Population                               0.025160
# S3_people_vaccinated                               0.021419
# CEN_Total Employer Establishments                  0.020184
# S3_people_fully_vaccinated                         0.017044
# CEN_Total Households                               0.015767
# FD_adminAndFireResponse                            0.015409
# S1_people_vaccinated                               0.014114
# CP_2_diff                                          0.011268
# CEN_Total Housing Units                            0.010702
# HB_bed_Total                                       0.009904
# S2_people_fully_vaccinated                         0.009593
# S1_people_vaccinated_per_hundred                   0.008198
# CEN_Bachelor's Degree or Higher                    0.007629
# CEN_Employment Rate                                0.007327
# S4_people_vaccinated_per_hundred                   0.007205
# S2_people_fully_vaccinated_per_hundred             0.006759
# S2_people_vaccinated_per_hundred                   0.006446
# FD_fireResponseOnly                                0.005605
# CEN_Median Household Income                        0.005241
# CP_1_diff                                          0.005238
# CP_0_diff                                          0.004889
# HB_bed_State/Local Government                      0.004558
# OB_Prevalence                                      0.004304
# HB_bed_Non-Profit                                  0.004285
# FD_lessThan10kCitizens                             0.004236
# HB_bed_For-Profit                                  0.004181
# S3_people_vaccinated_per_hundred                   0.003517
# FD_totalFireDepartments                            0.003452
# SP_Governor Political Affiliation                  0.002667
# SP_State House Majority Political Affiliation      0.002091
# S3_people_fully_vaccinated_per_hundred             0.001705
# SP_State Attorney General Political Affiliation    0.001309
# S4_people_fully_vaccinated_per_hundred             0.000907
# SP_State Senate Majority Political Affiliation     0.000071
