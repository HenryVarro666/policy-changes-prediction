# %% [markdown]
# # 2021 Policy Data

# %%
import pandas as pd

# %%
df=pd.read_csv('./data/data_policy_2021.csv')
df
# Out:
# /opt/homebrew/Caskroom/miniconda/base/envs/641/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3361: DtypeWarning: Columns (2,3,73) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0            Aruba         ABW        NaN        NaN    NAT_TOTAL  20210101
# 1            Aruba         ABW        NaN        NaN    NAT_TOTAL  20210102
# 2            Aruba         ABW        NaN        NaN    NAT_TOTAL  20210103
# 3            Aruba         ABW        NaN        NaN    NAT_TOTAL  20210104
# 4            Aruba         ABW        NaN        NaN    NAT_TOTAL  20210105
# ...            ...         ...        ...        ...          ...       ...
# 130300    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20211227
# 130301    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20211228
# ...

# %% [markdown]
# ## China policy data

# %%
df_CHN = df.loc[df['CountryName']=='China']
df_CHN
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 29200       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20210101
# 29201       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20210102
# 29202       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20210103
# 29203       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20210104
# 29204       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20210105
# ...           ...         ...        ...        ...          ...       ...
# 40875       China         CHN        NaN        NaN    NAT_TOTAL  20211227
# 40876       China         CHN        NaN        NaN    NAT_TOTAL  20211228
# 40877       China         CHN        NaN        NaN    NAT_TOTAL  20211229
# 40878       China         CHN        NaN        NaN    NAT_TOTAL  20211230
# 40879       China         CHN        NaN        NaN    NAT_TOTAL  20211231
#
#        C1_School closing  C1_Flag  \
# ...

# %%
df_CHN.to_csv(f'./data/2021 policy/CHN_policy_2021.csv')

# %% [markdown]
# ## America policy data

# %%
df_USA = df.loc[df['CountryCode']=='USA']
df_USA
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 108040  United States         USA        NaN        NaN    NAT_TOTAL
# 108041  United States         USA        NaN        NaN    NAT_TOTAL
# 108042  United States         USA        NaN        NaN    NAT_TOTAL
# 108043  United States         USA        NaN        NaN    NAT_TOTAL
# 108044  United States         USA        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 127015  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 127016  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 127017  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 127018  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 127019  United States         USA    Wyoming      US_WY  STATE_TOTAL
#
#             Date  C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  \
# ...

# %%
df_USA.to_csv(f'./data/2021 policy/USA_policy_2021.csv')

# %% [markdown]
# ## Italy policy data

# %%
df_ITA = df.loc[df['CountryName']=='Italy']
df_ITA
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 74095       Italy         ITA        NaN        NaN    NAT_TOTAL  20210101
# 74096       Italy         ITA        NaN        NaN    NAT_TOTAL  20210102
# 74097       Italy         ITA        NaN        NaN    NAT_TOTAL  20210103
# 74098       Italy         ITA        NaN        NaN    NAT_TOTAL  20210104
# 74099       Italy         ITA        NaN        NaN    NAT_TOTAL  20210105
# ...           ...         ...        ...        ...          ...       ...
# 74455       Italy         ITA        NaN        NaN    NAT_TOTAL  20211227
# 74456       Italy         ITA        NaN        NaN    NAT_TOTAL  20211228
# 74457       Italy         ITA        NaN        NaN    NAT_TOTAL  20211229
# 74458       Italy         ITA        NaN        NaN    NAT_TOTAL  20211230
# 74459       Italy         ITA        NaN        NaN    NAT_TOTAL  20211231
#
# ...

# %%
df_ITA.to_csv(f'./data/2021 policy/ITA_policy_2021.csv')

# %% [markdown]
# ## UK policy data

# %%
df_UK = df.loc[df['CountryName']=='United Kingdom']
df_UK
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 51100  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 51101  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 51102  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 51103  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 51104  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 52920  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 52921  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 52922  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 52923  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 52924  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
#
#            Date  C1_School closing  C1_Flag  \
# 51100  20210101                3.0      0.0
# 51101  20210102                3.0      0.0
# ...

# %%
df_UK.to_csv(f'./data/2021 policy/UK_policy_2021.csv')
