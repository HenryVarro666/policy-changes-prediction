# %% [markdown]
# # 2021 Policy Data

# %%
import pandas as pd

# %%
df=pd.read_csv('../data/data_policy_2020.csv')
df
# Out:
# /var/folders/c8/z7rkgj2x1fz_257xzx4c_vdh0000gn/T/ipykernel_41856/549924313.py:1: DtypeWarning: Columns (2,3,61,63,64,65,71,73) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('../data/data_policy_2020.csv')
#        CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0            Aruba         ABW        NaN        NaN    NAT_TOTAL  20200101
# 1            Aruba         ABW        NaN        NaN    NAT_TOTAL  20200102
# 2            Aruba         ABW        NaN        NaN    NAT_TOTAL  20200103
# 3            Aruba         ABW        NaN        NaN    NAT_TOTAL  20200104
# 4            Aruba         ABW        NaN        NaN    NAT_TOTAL  20200105
# ...            ...         ...        ...        ...          ...       ...
# 114553    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20201227
# 114554    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20201228
# ...

# %% [markdown]
# ## China policy data

# %%
df_CHN = df.loc[df['CountryName']=='China']
df_CHN
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 26352       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20200101
# 26353       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20200102
# 26354       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20200103
# 26355       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20200104
# 26356       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20200105
# ...           ...         ...        ...        ...          ...       ...
# 38059       China         CHN        NaN        NaN    NAT_TOTAL  20201227
# 38060       China         CHN        NaN        NaN    NAT_TOTAL  20201228
# 38061       China         CHN        NaN        NaN    NAT_TOTAL  20201229
# 38062       China         CHN        NaN        NaN    NAT_TOTAL  20201230
# 38063       China         CHN        NaN        NaN    NAT_TOTAL  20201231
#
# ...

# %%
df_CHN.to_csv(f'../data/2020_policy/CHN_policy_2020.csv')

# %% [markdown]
# ## America policy data

# %%
df_USA = df.loc[df['CountryCode']=='USA']
df_USA
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 92232   United States         USA        NaN        NaN    NAT_TOTAL
# 92233   United States         USA        NaN        NaN    NAT_TOTAL
# 92234   United States         USA        NaN        NaN    NAT_TOTAL
# 92235   United States         USA        NaN        NaN    NAT_TOTAL
# 92236   United States         USA        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 111259  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 111260  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 111261  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 111262  United States         USA    Wyoming      US_WY  STATE_TOTAL
# 111263  United States         USA    Wyoming      US_WY  STATE_TOTAL
#
#             Date  C1_School closing  C1_Flag  \
# 92232   20200101                0.0      NaN
# ...

# %%
df_USA.to_csv(f'../data/2020_policy/USA_policy_2020.csv')

# %% [markdown]
# ## Italy policy data

# %%
df_ITA = df.loc[df['CountryName']=='Italy']
df_ITA
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 58194       Italy         ITA        NaN        NaN    NAT_TOTAL  20200101
# 58195       Italy         ITA        NaN        NaN    NAT_TOTAL  20200102
# 58196       Italy         ITA        NaN        NaN    NAT_TOTAL  20200103
# 58197       Italy         ITA        NaN        NaN    NAT_TOTAL  20200104
# 58198       Italy         ITA        NaN        NaN    NAT_TOTAL  20200105
# ...           ...         ...        ...        ...          ...       ...
# 58555       Italy         ITA        NaN        NaN    NAT_TOTAL  20201227
# 58556       Italy         ITA        NaN        NaN    NAT_TOTAL  20201228
# 58557       Italy         ITA        NaN        NaN    NAT_TOTAL  20201229
# 58558       Italy         ITA        NaN        NaN    NAT_TOTAL  20201230
# 58559       Italy         ITA        NaN        NaN    NAT_TOTAL  20201231
#
# ...

# %%
df_ITA.to_csv(f'../data/2020_policy/ITA_policy_2020.csv')

# %% [markdown]
# ## UK policy data

# %%
df_UK = df.loc[df['CountryName']=='United Kingdom']
df_UK
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 48312  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 48313  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 48314  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 48315  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 48316  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 50137  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 50138  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 50139  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 50140  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 50141  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
#
#            Date  C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  \
# ...

# %%
df_UK.to_csv(f'../data/2020_policy/UK_policy_2020.csv')
