# %% [markdown]
# # 2021 Policy Data

# %%
import pandas as pd

# %%
df=pd.read_csv('../data/data_policy_2022.csv')
df
# Out:
# /var/folders/c8/z7rkgj2x1fz_257xzx4c_vdh0000gn/T/ipykernel_47519/2152067694.py:1: DtypeWarning: Columns (2,3,59) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('../data/data_policy_2022.csv')
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 0           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220101
# 1           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220102
# 2           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220103
# 3           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220104
# 4           Aruba         ABW        NaN        NaN    NAT_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 49618    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220515
# 49619    Zimbabwe         ZWE        NaN        NaN    NAT_TOTAL  20220516
# ...

# %% [markdown]
# ## China policy data

# %%
df_CHN = df.loc[df['CountryName']=='China']
df_CHN
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 11120       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220101
# 11121       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220102
# 11122       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220103
# 11123       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220104
# 11124       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 15563       China         CHN        NaN        NaN    NAT_TOTAL  20220515
# 15564       China         CHN        NaN        NaN    NAT_TOTAL  20220516
# 15565       China         CHN        NaN        NaN    NAT_TOTAL  20220517
# 15566       China         CHN        NaN        NaN    NAT_TOTAL  20220518
# 15567       China         CHN        NaN        NaN    NAT_TOTAL  20220519
#
# ...

# %%
df_CHN.head()
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 11120       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220101
# 11121       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220102
# 11122       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220103
# 11123       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220104
# 11124       China         CHN      Anhui     CHN_AH  STATE_TOTAL  20220105
#
#        C1_School closing  C1_Flag C1_Notes  C2_Workplace closing  ...  \
# 11120                1.0      1.0      NaN                   1.0  ...
# 11121                1.0      1.0      NaN                   1.0  ...
# 11122                1.0      1.0      NaN                   1.0  ...
# 11123                1.0      1.0      NaN                   1.0  ...
# 11124                1.0      1.0      NaN                   1.0  ...
#
#        StringencyIndex StringencyIndexForDisplay  StringencyLegacyIndex  \
# ...

# %%
### Numbers of columns

# %%
df_CHN.shape[1]
# Out:
# 86

# %%
### Numbers of lines

# %%
df_CHN.shape[0]
# Out:
# 4448

# %%
len(df_CHN)
# Out:
# 4448

# %%
df_CHN.to_csv(f'../data/2022_policy/CHN_policy_2022.csv')

# %% [markdown]
# ## America policy data

# %%
df_USA = df.loc[df['CountryCode']=='USA']
df_USA
# Out:
#          CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 41144  United States         USA        NaN        NaN    NAT_TOTAL  20220101
# 41145  United States         USA        NaN        NaN    NAT_TOTAL  20220102
# 41146  United States         USA        NaN        NaN    NAT_TOTAL  20220103
# 41147  United States         USA        NaN        NaN    NAT_TOTAL  20220104
# 41148  United States         USA        NaN        NaN    NAT_TOTAL  20220105
# ...              ...         ...        ...        ...          ...       ...
# 48367  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220515
# 48368  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220516
# 48369  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220517
# 48370  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220518
# 48371  United States         USA    Wyoming      US_WY  STATE_TOTAL  20220519
#
# ...

# %%
df_USA.to_csv(f'../data/2022_policy/USA_policy_2022.csv')

# %% [markdown]
# ## Italy policy data

# %%
df_ITA = df.loc[df['CountryName']=='Italy']
df_ITA
# Out:
#       CountryName CountryCode RegionName RegionCode Jurisdiction      Date  \
# 28217       Italy         ITA        NaN        NaN    NAT_TOTAL  20220101
# 28218       Italy         ITA        NaN        NaN    NAT_TOTAL  20220102
# 28219       Italy         ITA        NaN        NaN    NAT_TOTAL  20220103
# 28220       Italy         ITA        NaN        NaN    NAT_TOTAL  20220104
# 28221       Italy         ITA        NaN        NaN    NAT_TOTAL  20220105
# ...           ...         ...        ...        ...          ...       ...
# 28351       Italy         ITA        NaN        NaN    NAT_TOTAL  20220515
# 28352       Italy         ITA        NaN        NaN    NAT_TOTAL  20220516
# 28353       Italy         ITA        NaN        NaN    NAT_TOTAL  20220517
# 28354       Italy         ITA        NaN        NaN    NAT_TOTAL  20220518
# 28355       Italy         ITA        NaN        NaN    NAT_TOTAL  20220519
#
#        C1_School closing  C1_Flag  \
# ...

# %%
df_ITA.to_csv(f'../data/2022_policy/ITA_policy_2022.csv')

# %% [markdown]
# ## UK policy data

# %%
df_UK = df.loc[df['CountryName']=='United Kingdom']
df_UK
# Out:
#           CountryName CountryCode RegionName RegionCode Jurisdiction  \
# 19460  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 19461  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 19462  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 19463  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# 19464  United Kingdom         GBR        NaN        NaN    NAT_TOTAL
# ...               ...         ...        ...        ...          ...
# 20150  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 20151  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 20152  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 20153  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
# 20154  United Kingdom         GBR      Wales     UK_WAL  STATE_TOTAL
#
#            Date  C1_School closing  C1_Flag  \
# 19460  20220101                1.0      1.0
# 19461  20220102                1.0      1.0
# ...

# %%
df_UK.to_csv(f'../data/2022_policy/UK_policy_2022.csv')
